# %% [markdown]
# <a href="https://colab.research.google.com/github/techySPHINX/Python_Libraries_Learning/blob/main/project_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
from google.colab import drive

drive.mount('/content/gdrive')

import pandas as pd

data = pd.read_csv('/content/gdrive/My Drive/cardata.csv')

print(data.head())
# Out:
# Mounted at /content/gdrive
#   Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Selling_type Transmission  Owner
# 0       Dealer       Manual      0
# 1       Dealer       Manual      0
# 2       Dealer       Manual      0
# 3       Dealer       Manual      0
# 4       Dealer       Manual      0

# %%
data.describe()
# Out:
#               Year  Selling_Price  Present_Price     Driven_kms       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.642584   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
data['Selling_Price'].describe()
# Out:
# count    301.000000
# mean       4.661296
# std        5.082812
# min        0.100000
# 25%        0.900000
# 50%        3.600000
# 75%        6.000000
# max       35.000000
# Name: Selling_Price, dtype: float64

# %%
data.loc[data['Selling_Price'] == 4.60]
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 4    swift  2014            4.6           6.87       42450    Diesel
#
#   Selling_type Transmission  Owner
# 4       Dealer       Manual      0

# %%
data['Selling_Price'].mode()
# Out:
# 0    0.45
# 1    0.60
# Name: Selling_Price, dtype: float64

# %%
data['Selling_Price'].value_counts()
# Out:
# Selling_Price
# 0.45     8
# 0.60     8
# 5.25     7
# 4.50     7
# 0.20     6
#         ..
# 3.80     1
# 3.45     1
# 5.90     1
# 35.00    1
# 11.50    1
# Name: count, Length: 156, dtype: int64

# %%
data.shape
# Out:
# (301, 9)

# %%
data.describe(include='all')
# Out:
#        Car_Name         Year  Selling_Price  Present_Price     Driven_kms  \
# count       301   301.000000     301.000000     301.000000     301.000000
# unique       98          NaN            NaN            NaN            NaN
# top        city          NaN            NaN            NaN            NaN
# freq         26          NaN            NaN            NaN            NaN
# mean        NaN  2013.627907       4.661296       7.628472   36947.205980
# std         NaN     2.891554       5.082812       8.642584   38886.883882
# min         NaN  2003.000000       0.100000       0.320000     500.000000
# 25%         NaN  2012.000000       0.900000       1.200000   15000.000000
# 50%         NaN  2014.000000       3.600000       6.400000   32000.000000
# 75%         NaN  2016.000000       6.000000       9.900000   48767.000000
# max         NaN  2018.000000      35.000000      92.600000  500000.000000
#
#        Fuel_Type Selling_type Transmission       Owner
# ...

# %%
data['Selling_Price'].unique()
len(data['Selling_Price'].unique())
# Out:
# 156

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Driven_kms     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Selling_type   301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
data.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Driven_kms       0
# Fuel_Type        0
# Selling_type     0
# Transmission     0
# Owner            0
# dtype: int64

# %%
data['Selling_Price'] = data['Selling_Price'].fillna(data['Selling_Price'].mean())

# %%
data['Selling_Price'].isnull().sum()
# Out:
# 0

# %%
vdata = data.groupby('Year')['Driven_kms'].sum()
print(vdata)
# Out:
# Year
# 2003     189000
# 2004     135154
# 2005     417176
# 2006     349689
# 2007     102000
# 2008     784900
# 2009     406923
# 2010     900211
# 2011     766220
# 2012    1007359
# 2013    1370633
# 2014    1447052
# 2015    1958661
# 2016     919367
# 2017     364693
# 2018       2071
# Name: Driven_kms, dtype: int64

# %%
import matplotlib.pyplot as plt

vdata.plot(kind = 'bar')
# Out:
# <Axes: xlabel='Year'>
